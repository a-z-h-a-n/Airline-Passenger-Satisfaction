# %%
from datetime import datetime
print(f'Run time: {datetime.now().strftime("%D %T")}')
# Out:
# Run time: 05/08/25 22:12:44

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

# %%
# Reading the date fild into the dataframe
# The default seperator is
df = pd.read_csv("https://raw.githubusercontent.com/vjavaly/Baruch-CIS-3920/refs/heads/main/data/airline_passenger_satisfaction_100K.csv")
pd.set_option('display.max_columns', None)

# %%
# Displays the shape of the dataframe
df.shape
# Out:
# (100000, 25)

# %%
# Listing all the columns
df.columns
# Out:
# Index(['trip_id', 'passenger_id', 'Gender', 'Customer Type', 'Age',
#        'Type of Travel', 'Class', 'Flight Distance', 'Inflight WiFi',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
# Display a sample of 10 rows from the dataframe
df.sample(10)
# Out:
#        trip_id  passenger_id  Gender      Customer Type   Age  \
# 91304  8147975        423441  Female     Loyal Customer  27.0
# 81088  8020628        612065  Female     Loyal Customer  45.0
# 62160  6704660        622563  Female  disloyal Customer  19.0
# 31934  3081552        404822  Female     Loyal Customer  52.0
# 69840  2658197        610940    Male     Loyal Customer  41.0
# 65995  6086151        677068    Male     Loyal Customer  53.0
# 92916  1353911        703160    Male     Loyal Customer  60.0
# 30538  1456547        305687    Male  disloyal Customer  36.0
# 11198  8863175        685626    Male     Loyal Customer  51.0
# 28004  2253312        543036  Female     Loyal Customer  66.0
#
#         Type of Travel     Class  Flight Distance Inflight WiFi  \
# 91304  Business travel  Business            589.0          Poor
# 81088  Business travel       Eco           1046.0          Good
# 62160  Business travel  Eco Plus            784.0          Good
# 31934  Personal Travel       Eco            669.0     Excellent
# 69840  Personal Travel       Eco            328.0          Good
# 65995  Business travel  Business            957.0          Poor
# 92916  Business travel  Business           1578.0          Good
# 30538  Business travel       Eco            707.0          Good
# 11198  Personal Travel       Eco            358.0          Poor
# 28004  Personal Travel       Eco             73.0          Good
#
#       Departure/Arrival time convenient Ease of Online booking Gate location  \
# 91304                           Neutral                   Easy    Convenient
# 81088                           Neutral                Neutral       Neutral
# 62160                           Neutral                Neutral    Convenient
# 31934                           Neutral                   Easy    Convenient
# 69840                           Neutral              Difficult       Neutral
# 65995                           Neutral                Neutral       Neutral
# 92916                           Neutral                Neutral       Neutral
# 30538                           Neutral                Neutral    Convenient
# 11198                        Convenient              Difficult       Neutral
# 28004                        Convenient                Neutral       Neutral
#
#       Food and drink Online boarding   Seat comfort Inflight entertainment  \
# 91304           Poor             Bad  Uncomfortable                   Good
# 81088           Good         Average        Neutral                Neutral
# 62160           Good         Average    Comfortable                   Good
# 31934           Good            Good    Comfortable                   Poor
# 69840        Average             Bad        Neutral                Neutral
# 65995           Good            Good        Neutral                   Poor
# 92916           Good         Average        Neutral                Neutral
# 30538        Average         Average        Neutral                Neutral
# 11198        Average             Bad        Neutral                Neutral
# 28004        Average            Good    Comfortable                Neutral
#
#       On-board service Leg room  Baggage handling Checkin service  \
# 91304             Good     Good                 4            Poor
# 81088          Average  Average                 3         Average
# 62160             Good     Poor                 3         Average
# 31934             Poor     Good                 1            Good
# 69840             Poor  Average                 3            Poor
# 65995             Poor     Poor                 1            Poor
# 92916          Average  Average                 3            Good
# 30538             Good     Good                 4         Average
# 11198          Average  Average                 4            Good
# 28004          Average  Average                 2            Good
#
#       Inflight service  Cleanliness  Departure Delay in Minutes  \
# 91304             Good            1                       181.0
# 81088          Average            4                         4.0
# 62160             Good            4                         0.0
# 31934             Poor            3                         9.0
# 69840          Average            2                         9.0
# 65995             Poor            2                        76.0
# 92916          Average            2                        29.0
# 30538          Average            3                        43.0
# 11198             Good            2                         0.0
# 28004          Average            4                         0.0
#
#        Arrival Delay in Minutes             satisfaction
# 91304                     161.0  neutral or dissatisfied
# 81088                       0.0  neutral or dissatisfied
# 62160                       4.0  neutral or dissatisfied
# 31934                       8.0  neutral or dissatisfied
# 69840                       4.0  neutral or dissatisfied
# 65995                      70.0  neutral or dissatisfied
# 92916                      22.0  neutral or dissatisfied
# 30538                      34.0  neutral or dissatisfied
# 11198                       0.0  neutral or dissatisfied
# 28004                       0.0  neutral or dissatisfied

# %%
df.describe().T
# Out:
#                                count          mean           std        min  \
# trip_id                     100000.0  4.999477e+06  2.310205e+06  1000039.0
# passenger_id                100000.0  4.992850e+05  2.305950e+05   100000.0
# Age                          99310.0  3.791905e+01  1.616985e+01        7.0
# Flight Distance              99820.0  9.817266e+02  8.435440e+02       31.0
# Baggage handling            100000.0  3.422490e+00  1.184503e+00        1.0
# Cleanliness                 100000.0  3.010740e+00  1.331016e+00        0.0
# Departure Delay in Minutes   99762.0  1.600116e+01  4.008907e+01        0.0
# Arrival Delay in Minutes     99698.0  1.657830e+01  4.051119e+01        0.0
#
#                                    25%        50%        75%        max
# trip_id                     2997614.50  5004083.0  7001390.0  8999570.0
# passenger_id                 299844.25   498312.0   698853.5   899975.0
# Age                              25.00       37.0       50.0       85.0
# Flight Distance                 383.00      689.0     1235.0     4983.0
# Baggage handling                  3.00        4.0        4.0        5.0
# Cleanliness                       2.00        3.0        4.0        5.0
# Departure Delay in Minutes        0.00        0.0       14.0     1592.0
# Arrival Delay in Minutes          0.00        0.0       16.0     1584.0

# %%
# Display bar chart of class distribution
df['satisfaction'].value_counts().sort_index().plot(kind='bar', color='skyblue', title='Satisfaction Distribution of Passengers').figure.tight_layout()

# %%
unique_counts = df.nunique()
print(unique_counts)
# Out:
# trip_id                              99971
# passenger_id                         99971
# Gender                                   2
# Customer Type                            2
# Age                                     75
# Type of Travel                           2
# Class                                    3
# Flight Distance                       3505
# Inflight WiFi                            3
# Departure/Arrival time convenient        3
# Ease of Online booking                   3
# Gate location                            3
# Food and drink                           3
# Online boarding                          3
# Seat comfort                             3
# Inflight entertainment                   3
# On-board service                         3
# Leg room                                 3
# Baggage handling                         5
# Checkin service                          3
# Inflight service                         3
# Cleanliness                              6
# Departure Delay in Minutes             389
# Arrival Delay in Minutes               400
# 69096          Average  Average                 3            Good
# 69340          Average     Good                 2         Average
# 74335             Good  Average                 4            Good
# 75451             Poor  Average                 4         Average
# 77222             Good     Good                 2            Good
# 78043          Average  Average                 1            Poor
# 78049             Good     Good                 5            Good
# 79002             Good  Average                 4         Average
# 79642             Good     Good                 4            Good
# 80528             Good     Good                 1            Poor
# 84635             Poor     Poor                 4         Average
# 84840             Good  Average                 4            Good
# 86436             Poor     Poor                 4            Poor
# 87029          Average  Average                 5            Good
# 88652          Average     Good                 5            Good
# 89823          Average  Average                 5            Good
# 90166              NaN     Good                 4         Average
# 91805          Average  Average                 4            Good
# 95355          Average  Average                 1         Average
# 96608          Average     Good                 1            Good
#
#       Inflight service  Cleanliness  Departure Delay in Minutes  \
# 14298             Good            2                        20.0
# 32634          Average            2                         0.0
# 34995             Good            4                         0.0
# 40739          Average            1                         0.0
# 42543             Good            5                         0.0
# 43911             Good            5                         0.0
# 54930             Poor            5                         0.0
# 62770             Good            1                         6.0
# 64638          Average            2                         0.0
# 69096          Average            2                        14.0
# 69340             Poor            4                         0.0
# 74335             Good            3                         0.0
# 75451          Average            4                        79.0
# 77222             Poor            4                        16.0
# 78043             Poor            4                        11.0
# 78049             Good            5                         0.0
# 79002             Good            5                        40.0
# 79642             Good            4                         0.0
# 80528          Average            5                         8.0
# 84635          Average            4                         0.0
# 84840             Good            4                         0.0
# 86436          Average            5                         0.0
# 87029             Good            4                         0.0
# 88652             Good            2                         3.0
# 89823             Good            4                         0.0
# 90166             Good            1                         9.0
# 91805             Good            2                        42.0
# 95355          Average            3                         0.0
# 96608          Average            4                         0.0
#
#        Arrival Delay in Minutes             satisfaction
# 14298                      13.0  neutral or dissatisfied
# 32634                       0.0  neutral or dissatisfied
# 34995                       7.0  neutral or dissatisfied
# 40739                       9.0  neutral or dissatisfied
# 42543                       0.0  neutral or dissatisfied
# 43911                       0.0  neutral or dissatisfied
# 54930                       0.0  neutral or dissatisfied
# 62770                       1.0  neutral or dissatisfied
# 64638                       2.0  neutral or dissatisfied
# 69096                      29.0  neutral or dissatisfied
# 69340                       0.0  neutral or dissatisfied
# 74335                      10.0  neutral or dissatisfied
# 75451                      62.0  neutral or dissatisfied
# 77222                       7.0  neutral or dissatisfied
# 78043                       4.0  neutral or dissatisfied
# 78049                       0.0                satisfied
# 79002                      44.0  neutral or dissatisfied
# 79642                       0.0  neutral or dissatisfied
# 80528                      29.0                satisfied
# 84635                      17.0  neutral or dissatisfied
# 84840                      11.0  neutral or dissatisfied
# 86436                       0.0  neutral or dissatisfied
# 87029                       0.0  neutral or dissatisfied
# 88652                       0.0  neutral or dissatisfied
# 89823                       1.0  neutral or dissatisfied
# 90166                       2.0  neutral or dissatisfied
# 91805                      27.0  neutral or dissatisfied
# 95355                       0.0  neutral or dissatisfied
# 96608                       0.0  neutral or dissatisfied

# %%
# Dropping the duplicates in the dataframe
df.drop_duplicates()
# Out:
#        trip_id  passenger_id  Gender      Customer Type   Age  \
# 0      5438431        139868    Male     Loyal Customer  38.0
# 1      7051759        218745    Male     Loyal Customer  63.0
# 2      4894365        873222    Male  disloyal Customer  27.0
# 3      2443272        249550    Male  disloyal Customer  41.0
# 4      3603635        128206  Female     Loyal Customer  48.0
# ...        ...           ...     ...                ...   ...
# 99995  3770674        844223  Female     Loyal Customer  67.0
# 99996  5602314        369962  Female     Loyal Customer  63.0
# 99997  4985496        398298    Male     Loyal Customer  41.0
# 99998  8331068        309876  Female     Loyal Customer  54.0
# 99999  4607184        127422    Male     Loyal Customer  68.0
#
#         Type of Travel     Class  Flight Distance Inflight WiFi  \
# 0      Personal Travel       Eco            634.0          Good
# 1      Business travel  Eco Plus            115.0     Excellent
# 2      Business travel       Eco            719.0          Good
# 3      Business travel  Eco Plus            591.0          Poor
# 4      Business travel  Business           3358.0     Excellent
# ...                ...       ...              ...           ...
# 99995  Personal Travel  Eco Plus            429.0          Good
# 99996  Personal Travel       Eco           1190.0          Good
# 99997  Business travel  Eco Plus            964.0          Poor
# 99998  Personal Travel       Eco           1126.0          Poor
# 99999  Personal Travel       Eco            174.0          Good
#
#       Departure/Arrival time convenient Ease of Online booking Gate location  \
# 0                            Convenient                Neutral       Neutral
# 1                          Inconvenient              Difficult  Inconvenient
# 2                               Neutral                Neutral       Neutral
# 3                          Inconvenient              Difficult       Neutral
# 4                               Neutral                   Easy    Convenient
# ...                                 ...                    ...           ...
# 99995                           Neutral                Neutral       Neutral
# 99996                        Convenient                Neutral  Inconvenient
# 99997                           Neutral                Neutral       Neutral
# 99998                           Neutral              Difficult       Neutral
# 99999                           Neutral                Neutral    Convenient
#
#       Food and drink Online boarding Seat comfort Inflight entertainment  \
# 0               Good         Average      Neutral                   Good
# 1               Good            Good  Comfortable                   Good
# 2               Good         Average  Comfortable                   Good
# 3               Poor            Good  Comfortable                Neutral
# 4               Good         Average  Comfortable                   Good
# ...              ...             ...          ...                    ...
# 99995        Average         Average      Neutral                Neutral
# 99996           Good            Good  Comfortable                Neutral
# 99997           Poor             Bad          NaN                   Poor
# 99998        Average            Good  Comfortable                   Good
# 99999        Average         Average      Neutral                Neutral
#
#       On-board service Leg room  Baggage handling Checkin service  \
# 0                 Good  Average                 5         Average
# 1                 Good     Good                 4            Good
# 2              Average  Average                 2         Average
# 3              Average  Average                 3            Good
# 4                 Good     Good                 5         Average
# ...                ...      ...               ...             ...
# 99995          Average  Average                 3            Good
# 99996          Average  Average                 3            Good
# 99997          Average     Good                 4            Poor
# 99998             Good     Poor                 4            Good
# 99999          Average  Average                 5            Good
#
#       Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 Good            4                         0.0
# 1                 Good            4                         0.0
# 2              Average            4                         1.0
# 3                 Poor            5                       306.0
# 4                 Good            3                       112.0
# ...                ...          ...                         ...
# 99995          Average            1                       120.0
# 99996          Average            4                        32.0
# 99997          Average            1                        14.0
# 99998             Good            5                         0.0
# 99999             Good            3                         0.0
#
#        Arrival Delay in Minutes             satisfaction
# 0                           0.0  neutral or dissatisfied
# 1                           2.0                satisfied
# 2                           9.0  neutral or dissatisfied
# 3                         295.0  neutral or dissatisfied
# 4                         130.0                satisfied
# ...                         ...                      ...
# 99995                     113.0  neutral or dissatisfied
# 99996                      16.0  neutral or dissatisfied
# 99997                       0.0  neutral or dissatisfied
# 99998                       0.0  neutral or dissatisfied
# 99999                       0.0  neutral or dissatisfied
#
# [99971 rows x 25 columns]

# %%
df.drop(columns=["trip_id","passenger_id"], inplace=True)

# %%
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imp_mode = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Gender                               2386
# Customer Type                           0
# Age                                   690
# Type of Travel                          0
# Class                                   0
# Flight Distance                       180
# Inflight WiFi                         555
# Departure/Arrival time convenient       0
# Ease of Online booking                  0
# Gate location                           0
# Food and drink                       1056
# Online boarding                         0
# Seat comfort                          401
# Inflight entertainment                170
# On-board service                      228
# Leg room                              133
# Baggage handling                        0
# Checkin service                         0
# Inflight service                      132
# Cleanliness                             0
# Departure Delay in Minutes            238
# Arrival Delay in Minutes              302
# satisfaction                            0
# dtype: int64

# %%
columns_numerical = ["Age","Flight Distance","Departure Delay in Minutes","Arrival Delay in Minutes"]
columns_non_numerical= ["Gender", "Inflight WiFi", "Food and drink", "Seat comfort", "Inflight entertainment", "On-board service", "Leg room", "Inflight service"]

# %%
df[columns_numerical] = imp_mean.fit_transform(df[columns_numerical])
df[columns_non_numerical] = imp_mode.fit_transform(df[columns_non_numerical])

# %%
# Re-check for missing values
df.isnull().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight WiFi                        0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room                             0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %%
print(df["Class"].unique())
print(df["Ease of Online booking"].unique())
print(df["On-board service"].unique())
print(df["Leg room"].unique())
print(df["Inflight WiFi"].unique())
print(df["Gate location"].unique())
print(df["Inflight entertainment"].unique())
print(df["Departure/Arrival time convenient"].unique())
print(df["Inflight service"].unique())
print(df["Checkin service"].unique())
print(df["Food and drink"].unique())
print(df["Online boarding"].unique())
print(df["Seat comfort"].unique())
# Out:
# ['Eco' 'Eco Plus' 'Business']
# ['Neutral' 'Difficult' 'Easy']
# ['Good' 'Average' 'Poor']
# ['Average' 'Good' 'Poor']
# ['Good' 'Excellent' 'Poor']
# ['Neutral' 'Inconvenient' 'Convenient']
# ['Good' 'Neutral' 'Poor']
# ['Convenient' 'Inconvenient' 'Neutral']
# ['Good' 'Average' 'Poor']
# ['Average' 'Good' 'Poor']
# ['Good' 'Poor' 'Average']
# ['Average' 'Good' 'Bad']
# ['Neutral' 'Comfortable' 'Uncomfortable']

# %%
CATEGORIES = [['Eco', 'Eco Plus', 'Business'], ['Neutral', 'Difficult', 'Easy'], ['Poor', 'Average', 'Good'], ['Poor', 'Average', 'Good'], ['Poor', 'Good', 'Excellent'], ['Inconvenient', 'Neutral', 'Convenient'], ['Poor','Neutral','Good'], ['Inconvenient', 'Neutral', 'Convenient'], ["Poor","Average", "Good"], ["Poor","Average", "Good"], ["Poor","Average", "Good"], ['Bad','Average','Good'], ['Uncomfortable','Neutral','Comfortable']]

# Initialize the OrdinalEncoder
oe = OrdinalEncoder(categories=CATEGORIES)

# Generate encodings
df[['Class', 'Ease of Online booking', "On-board service", "Leg room", "Inflight WiFi", "Gate location", "Inflight entertainment", "Departure/Arrival time convenient", "Inflight service", "Checkin service", "Food and drink", "Online boarding", "Seat comfort"]] = oe.fit_transform(df[['Class', 'Ease of Online booking', "On-board service", "Leg room", 'Inflight WiFi', "Gate location", "Inflight entertainment", "Departure/Arrival time convenient", "Inflight service", "Checkin service", "Food and drink", "Online boarding", "Seat comfort"]])
#
df.sample(10)
# Out:
#        Gender      Customer Type   Age   Type of Travel  Class  \
# 63164    Male     Loyal Customer  26.0  Business travel    2.0
# 32275    Male     Loyal Customer  27.0  Personal Travel    2.0
# 64804    Male  disloyal Customer  25.0  Business travel    0.0
# 46894    Male     Loyal Customer  49.0  Business travel    1.0
# 87767  Female  disloyal Customer  23.0  Business travel    0.0
# 79185    Male     Loyal Customer  24.0  Personal Travel    0.0
# 49920  Female     Loyal Customer  42.0  Business travel    2.0
# 90148    Male     Loyal Customer  48.0  Business travel    2.0
# 94938  Female     Loyal Customer  66.0  Personal Travel    0.0
# 90346  Female     Loyal Customer  28.0  Personal Travel    0.0
#
#        Flight Distance  Inflight WiFi  Departure/Arrival time convenient  \
# 63164           2603.0            2.0                                2.0
# 32275           1009.0            1.0                                1.0
# 64804            261.0            1.0                                0.0
# 46894            667.0            1.0                                1.0
# 87767            606.0            2.0                                0.0
# 79185            726.0            1.0                                1.0
# 49920           2381.0            0.0                                0.0
# 90148           2392.0            1.0                                1.0
# 94938            682.0            1.0                                2.0
# 90346           1744.0            0.0                                1.0
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 63164                     2.0            2.0             2.0              2.0
# 32275                     0.0            1.0             1.0              1.0
# 64804                     0.0            0.0             1.0              1.0
# 46894                     2.0            2.0             1.0              1.0
# 87767                     2.0            1.0             2.0              2.0
# 79185                     0.0            1.0             1.0              1.0
# 49920                     0.0            0.0             1.0              2.0
# 90148                     0.0            1.0             1.0              1.0
# 94938                     0.0            2.0             1.0              2.0
# 90346                     1.0            1.0             0.0              2.0
#
#        Seat comfort  Inflight entertainment  On-board service  Leg room  \
# 63164           2.0                     2.0               0.0       0.0
# 32275           1.0                     1.0               1.0       0.0
# 64804           2.0                     1.0               1.0       2.0
# 46894           1.0                     1.0               1.0       1.0
# 87767           2.0                     2.0               1.0       1.0
# 79185           1.0                     1.0               2.0       0.0
# 49920           1.0                     2.0               2.0       2.0
# 90148           2.0                     1.0               1.0       1.0
# 94938           2.0                     1.0               1.0       1.0
# 90346           2.0                     2.0               2.0       1.0
#
#        Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 63164                 1              1.0               1.0            4
# 32275                 2              1.0               1.0            2
# 64804                 1              1.0               1.0            2
# 46894                 2              2.0               1.0            2
# 87767                 4              1.0               2.0            5
# 79185                 4              0.0               1.0            2
# 49920                 5              1.0               2.0            2
# 90148                 3              1.0               1.0            1
# 94938                 2              2.0               1.0            4
# 90346                 3              2.0               1.0            4
#
#        Departure Delay in Minutes  Arrival Delay in Minutes  \
# 63164                        73.0                      51.0
# 32275                         0.0                       0.0
# 64804                         0.0                       0.0
# 46894                        35.0                      39.0
# 87767                        64.0                      68.0
# 79185                         0.0                       0.0
# 49920                         9.0                       6.0
# 90148                        14.0                      17.0
# 94938                         2.0                      13.0
# 90346                       138.0                     106.0
#
#                   satisfaction
# 63164  neutral or dissatisfied
# 32275  neutral or dissatisfied
# 64804  neutral or dissatisfied
# 46894  neutral or dissatisfied
# 87767                satisfied
# 79185  neutral or dissatisfied
# 49920                satisfied
# 90148  neutral or dissatisfied
# 94938  neutral or dissatisfied
# 90346  neutral or dissatisfied

# %%
df = pd.get_dummies(df, columns=['Gender', 'Customer Type', "Type of Travel" ], drop_first=True, dtype=int,)
df.sample(10)
# Out:
#         Age  Class  Flight Distance  Inflight WiFi  \
# 8555   48.0    0.0            846.0            1.0
# 92385  10.0    0.0            390.0            1.0
# 72541  52.0    0.0            696.0            1.0
# 20590  65.0    2.0           1142.0            0.0
# 74110  38.0    2.0            391.0            1.0
# 21445  31.0    2.0           1891.0            2.0
# 81497  22.0    0.0            184.0            0.0
# 16362  52.0    2.0            690.0            0.0
# 6353   31.0    2.0           3440.0            1.0
# 54683  29.0    2.0           2524.0            0.0
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# 8555                                 1.0                     0.0
# 92385                                0.0                     0.0
# 72541                                1.0                     0.0
# 20590                                1.0                     0.0
# 74110                                1.0                     0.0
# 21445                                1.0                     2.0
# 81497                                0.0                     1.0
# 16362                                0.0                     1.0
# 6353                                 1.0                     0.0
# 54683                                2.0                     2.0
#
#        Gate location  Food and drink  Online boarding  Seat comfort  \
# 8555             1.0             1.0              1.0           1.0
# 92385            1.0             1.0              1.0           1.0
# 72541            1.0             2.0              1.0           2.0
# 20590            2.0             2.0              2.0           2.0
# 74110            1.0             1.0              1.0           1.0
# 21445            2.0             2.0              1.0           2.0
# 81497            1.0             1.0              0.0           1.0
# 16362            1.0             1.0              0.0           2.0
# 6353             1.0             1.0              1.0           1.0
# 54683            2.0             0.0              0.0           0.0
#
#        Inflight entertainment  On-board service  Leg room  Baggage handling  \
# 8555                      1.0               0.0       2.0                 1
# 92385                     1.0               1.0       0.0                 4
# 72541                     2.0               2.0       1.0                 5
# 20590                     2.0               2.0       1.0                 5
# 74110                     1.0               2.0       1.0                 5
# 21445                     2.0               2.0       1.0                 4
# 81497                     1.0               0.0       2.0                 3
# 16362                     2.0               0.0       2.0                 3
# 6353                      1.0               1.0       2.0                 3
# 54683                     0.0               0.0       2.0                 3
#
#        Checkin service  Inflight service  Cleanliness  \
# 8555               1.0               2.0            3
# 92385              1.0               1.0            2
# 24240                     2.0               2.0       1.0                 4
# 85001                     2.0               1.0       2.0                 5
#
#        Checkin service  Inflight service  Cleanliness  \
# 60741              1.0               2.0            1
# 58193              2.0               2.0            3
# 87465              2.0               2.0            5
# 53433              1.0               1.0            4
# 44120              1.0               1.0            3
# 88507              2.0               2.0            3
# 43203              2.0               1.0            5
# 66298              1.0               1.0            4
# 24240              2.0               2.0            5
# 85001              1.0               2.0            5
#
#        Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction  \
# 60741                         0.0                       0.0             0
# 58193                        19.0                      16.0             0
# 87465                         0.0                       0.0             0
# 53433                        18.0                       0.0             0
# 44120                         0.0                       0.0             0
# 88507                         0.0                      17.0             0
# 43203                        14.0                       6.0             0
# 66298                         0.0                       0.0             0
# 24240                       130.0                     110.0             0
# 85001                         0.0                       0.0             0
#
#        Gender_Male  Customer Type_disloyal Customer  \
# 60741            1                                0
# 58193            0                                0
# 87465            0                                0
# 53433            0                                0
# 44120            1                                0
# 88507            0                                1
# 43203            1                                0
# 66298            0                                0
# 24240            0                                0
# 85001            0                                0
#
#        Type of Travel_Personal Travel
# 60741                               1
# 58193                               1
# 87465                               1
# 53433                               0
# 44120                               0
# 88507                               0
# 43203                               1
# 66298                               1
# 24240                               1
# 85001                               1

# %%
X = df.drop(columns="satisfaction", axis = 1)
y = df["satisfaction"]

# %%
# Instantiate StandardScalar
scaler = StandardScaler()

# Scale the independent variables
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

# %%
sm = SMOTE(sampling_strategy=0.3)
X_sm, y_sm = sm.fit_resample(X_scaled, y)

# %%
# Displaying a sample of 5 rows of the final set of independent variables used for model training
# Convert X_sm to a Pandas DataFrame before calling sample()
X_sm_df = pd.DataFrame(X_sm, columns=X.columns)  # Assuming X is the original DataFrame with column names
X_sm_df.sample(5)
# Out:
#              Age     Class  Flight Distance  Inflight WiFi  \
# 117315 -0.358748  1.456480        -0.357650       1.698778
# 46083  -0.057035  1.456480         2.375795       0.042694
# 104877  0.804397  1.456480         0.050054       0.042694
# 29454   0.005024 -0.763781        -0.781611      -1.613391
# 92578   1.866772 -0.763781        -0.175285       0.042694
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 117315                          -0.047664                1.578592
# 46083                           -1.625419                0.376954
# 104877                          -0.047664                1.578592
# 29454                           -0.047664                0.376954
# 92578                           -0.047664               -0.824684
#
#         Gate location  Food and drink  Online boarding  Seat comfort  \
# 117315       1.163407       -0.311186         1.311161     -0.397215
# 46083       -1.750684        1.106390        -0.199672     -1.810038
# 104877      -0.293638       -0.311186         1.311161      1.015608
# 29454       -0.293638        1.106390        -1.710505     -1.810038
# 92578       -1.750684       -0.311186        -0.199672     -0.397215
#
#         Inflight entertainment  On-board service  Leg room  Baggage handling  \
# 117315               -0.296336          1.047604  1.087944          0.487557
# 46083                -0.296336         -0.372183 -0.381754         -1.200924
# 104877                1.107702          1.047604  1.087944          1.331798
# 29454                 1.107702          1.047604 -0.381754          0.487557
# 92578                -0.296336         -0.372183 -0.381754          1.331798
#
#         Checkin service  Inflight service  Cleanliness  \
# 117315         0.453477          0.846114    -0.447347
# 46083         -0.365355         -0.710645    -0.759379
# 104877        -0.365355          0.846114     0.598511
# 29454         -0.365355          0.846114     0.743241
# 92578         -0.365355          0.846114    -0.008069
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  Gender_Male  \
# 117315                   -0.399618                 -0.409849    -0.951190
# 46083                     1.398533                  2.284851     1.051315
# 104877                   -0.399618                 -0.270131    -0.951190
# 29454                    -0.399618                 -0.409849     1.051315
# 92578                    -0.399618                  0.109313     1.051315
#
#         Customer Type_disloyal Customer  Type of Travel_Personal Travel
# 117315                         1.820150                       -0.919656
# 46083                         -0.549405                       -0.919656
# 104877                        -0.549405                       -0.919656
# 29454                         -0.549405                        1.087363
# 92578                         -0.549405                        1.087363

# %%
# Display a sample of 5 rows from the final dependent variable used for model training
y.sample(5)
# Out:
# 34047    0
# 31233    0
# 58956    0
# 88324    0
# 95187    0
# Name: satisfaction, dtype: int32

# %%
# Split data into training and test sets
X_train_sm, X_test_sm, y_train_sm, y_test_sm = train_test_split(X_sm, y_sm,
                                                                stratify=y_sm,
                                                                test_size=0.25)

# %%
# Display model (default) hyperparameters
model = LogisticRegression()
model.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Parameter grid
param_dist = {
    'C': [0.01, 0.1, 1, 10],
    'solver': ['liblinear', 'lbfgs'],
    'max_iter': [100, 200, 300],
    'fit_intercept': [True, False]
}

# RandomizedSearchCV 
rs = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_dist,
    n_iter=6,         
    scoring='accuracy',
    cv=3,
    n_jobs=-1
)

# Fit the search
rs.fit(X_train_sm, y_train_sm)

# Evaluate
best_logreg_model = rs.best_estimator_
accuracy = best_logreg_model.score(X_test_sm, y_test_sm)

print(f"Best Parameters: {rs.best_params_}")
print(f"Model Score: {round(accuracy * 100, 2)}%")
# Out:
# Best Parameters: {'solver': 'liblinear', 'max_iter': 100, 'fit_intercept': True, 'C': 0.01}
# Model Score: 91.34%

# %%
# Predict using the test set
y_pred_sm = best_logreg_model.predict(X_test_sm)

# %%
# Display model accuracy score
accuracy = best_logreg_model.score(X_test_sm, y_test_sm)
print("accuracy =", round((accuracy * 100), 2), "%")
# Out:
# accuracy = 91.34 %

# %%
# Display classification report
print(classification_report(y_test_sm, y_pred_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94     22853
#            1       0.84      0.77      0.80      6856
#
#     accuracy                           0.91     29709
#    macro avg       0.89      0.86      0.87     29709
# weighted avg       0.91      0.91      0.91     29709

# %%
# Generate confusion matrix
cm = confusion_matrix(y_test_sm, y_pred_sm)
cm
# Out:
# array([[21868,   985],
#        [ 1588,  5268]], dtype=int64)

# %%
# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=best_logreg_model.classes_)
disp.plot()
plt.show()

# %%
# Display ROC Curve
y_pred_sm_proba = best_logreg_model.predict_proba(X_test_sm)[::,1]
fpr, tpr, _ = roc_curve(y_test_sm, y_pred_sm_proba)
auc = round(roc_auc_score(y_test_sm, y_pred_sm_proba),4)
gini = round(((auc * 2) - 1),4)
label_string = f'AUC={auc}, Gini={gini}'
plt.plot(fpr, tpr, label=label_string)
plt.legend(loc=4)
plt.title('ROC curve', y=1.05)
plt.ylabel('True positive rate')
plt.xlabel('False positive rate')
plt.show()

# %%
# Extract feature names
labels = list(X.columns)
labels
# Out:
# ['Age',
#  'Class',
#  'Flight Distance',
#  'Inflight WiFi',
#  'Departure/Arrival time convenient',
#  'Ease of Online booking',
#  'Gate location',
#  'Food and drink',
#  'Online boarding',
#  'Seat comfort',
#  'Inflight entertainment',
#  'On-board service',
#  'Leg room',
#  'Baggage handling',
#  'Checkin service',
#  'Inflight service',
#  'Cleanliness',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes',
#  'Gender_Male',
#  'Customer Type_disloyal Customer',
#  'Type of Travel_Personal Travel']

# %%
coeff = list(best_logreg_model.coef_[0])
coeff
# Out:
# [-0.0329318106332027,
#  0.36059103664460823,
#  -0.01027640555088865,
#  0.4222029819761414,
#  -0.16942153690114037,
#  0.2929059330537409,
#  -0.09432608400203435,
#  -0.006238124315983331,
#  0.7194595765396707,
#  0.21515864005021418,
#  -0.0760783397318666,
#  0.39614503645766347,
#  0.3678511999800446,
#  0.35377406848605464,
#  0.37028671289085535,
#  0.2173125193698915,
#  0.4755683301891481,
#  -0.00831251513994689,
#  -0.1802561130423827,
#  0.04886880832361376,
#  -0.917974010131263,
#  -1.380325183297275]

# %%
# Visualize how the model uses different features and which features have greater effect
features = pd.DataFrame()
features['Features'] = labels
features['importance'] = coeff
features.sort_values(by=['importance'], ascending=True, inplace=True)
features['positive'] = features['importance'] > 0
features.set_index('Features', inplace=True)
features.importance.plot(kind='barh', figsize=(8, 4),
                         color = features.positive.map({True: 'blue', False: 'red'}))
plt.xlabel('Importance')
plt.show()

# %%
model_2 = KNeighborsClassifier()
model_2.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
#Define parameter grid 
param_dist = {
    'n_neighbors': [3, 5, 7],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan'],
    'algorithm': ['auto'],
}

#Setup RandomizedSearchCV
rs = RandomizedSearchCV(
    estimator=model_2,
    param_distributions=param_dist,
    n_iter=10,
    scoring='accuracy',
    cv=2,
    n_jobs=1,        
    verbose=1,)


# Step 4: Fit and evaluate
rs.fit(X_train_sm, y_train_sm)
best_knn_model = rs.best_estimator_
accuracy = best_knn_model.score(X_test_sm, y_test_sm)

print(f"Best Parameters: {rs.best_params_}")
print(f"Model Score: {round(accuracy * 100, 2)}%")
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# Best Parameters: {'weights': 'distance', 'n_neighbors': 3, 'metric': 'manhattan', 'algorithm': 'auto'}
# Model Score: 99.03%

# %%
# Predict using the test set
y_pred_sm = best_knn_model.predict(X_test_sm)
y_pred_sm
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
accuracy = best_knn_model.score(X_test_sm, y_test_sm)
print("accuracy =", round((accuracy * 100), 2), "%")
# Out:
# accuracy = 99.03 %

# %%
print(classification_report(y_test_sm, y_pred_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     22853
#            1       0.97      0.99      0.98      6856
#
#     accuracy                           0.99     29709
#    macro avg       0.98      0.99      0.99     29709
# weighted avg       0.99      0.99      0.99     29709

# %%
cm = confusion_matrix(y_test_sm, y_pred_sm)
cm
# Out:
# array([[22663,   190],
#        [   97,  6759]], dtype=int64)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=best_knn_model.classes_)
disp.plot()
plt.show()

# %%
y_pred_sm_proba = best_knn_model.predict_proba(X_test_sm)[::,1]
fpr, tpr, _ = roc_curve(y_test_sm, y_pred_sm_proba)
auc = round(roc_auc_score(y_test_sm, y_pred_sm_proba),4)
gini = round(((auc * 2) - 1),4)
label_string = f'AUC={auc}, Gini={gini}'
plt.plot(fpr, tpr, label=label_string)
plt.legend(loc=4)
plt.title('ROC curve', y=1.05)
plt.ylabel('True positive rate')
plt.xlabel('False positive rate')
plt.show()

# %%
model_3=RandomForestClassifier()
model_3.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Simple parameter distribution
param_dist = {
    'n_estimators': randint(50, 100),
    'max_depth': [None, 10, 20],
}

# RandomizedSearchCV setup
rs = RandomizedSearchCV(
    model_3,
    param_distributions=param_dist,
    n_iter=5,
    cv=3,
    scoring='accuracy',
    n_jobs=-1,
    verbose=1
)

# Fit to training data
rs.fit(X_train_sm, y_train_sm)

# Print best parameters
print(rs.best_params_)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# {'max_depth': None, 'n_estimators': 73}

# %%
best_rf_model = rs.best_estimator_
best_rf_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 73,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Use best model to make predictions on the test set
y_pred_sm = best_rf_model.predict(X_test_sm)

# %%
# Print best model accuracy score
best_random_search_accuracy = round((best_rf_model.score(X_test_sm, y_test_sm) * 100), 3)
print(f"Best model after random search accuracy = {best_random_search_accuracy}%")
# Out:
# Best model after random search accuracy = 99.28%

# %%
# Display classification report
print(classification_report(y_test_sm, y_pred_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     22853
#            1       1.00      0.97      0.98      6856
#
#     accuracy                           0.99     29709
#    macro avg       0.99      0.99      0.99     29709
# weighted avg       0.99      0.99      0.99     29709

# %%
cm = confusion_matrix(y_test_sm, y_pred_sm)
cm
# Out:
# array([[22823,    30],
#        [  184,  6672]], dtype=int64)

# %%
# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=best_rf_model.classes_)
disp.plot()
plt.show()

# %%
feature_names = X.columns
feature_names
# Out:
# Index(['Age', 'Class', 'Flight Distance', 'Inflight WiFi',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'Gender_Male', 'Customer Type_disloyal Customer',
#        'Type of Travel_Personal Travel'],
#       dtype='object')

# %%
feature_importances = best_rf_model.feature_importances_
feature_importances
# Out:
# array([0.0472273 , 0.11638274, 0.04563589, 0.06817798, 0.01584239,
#        0.01874734, 0.02359282, 0.01444152, 0.15439587, 0.04676879,
#        0.05789414, 0.02652859, 0.04648308, 0.05147676, 0.02347239,
#        0.02385177, 0.04816868, 0.01855497, 0.02024417, 0.00864901,
#        0.03887208, 0.0845917 ])

# %%
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

# %%
# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.gca().invert_yaxis()  # Invert to show the most important feature at the top
plt.show()

# %%
y_pred_sm_proba = best_rf_model.predict_proba(X_test_sm)[::,1]
fpr, tpr, _ = roc_curve(y_test_sm, y_pred_sm_proba)
auc = round(roc_auc_score(y_test_sm, y_pred_sm_proba),4)
gini = round(((auc * 2) - 1),4)
label_string = f'AUC={auc}, Gini={gini}'
plt.plot(fpr, tpr, label=label_string)
plt.legend(loc=4)
plt.title('ROC curve', y=1.05)
plt.ylabel('True positive rate')
plt.xlabel('False positive rate')
plt.show()

# %%
# Step 1: Define the model
model_4 = LinearSVC(dual=False)

# Step 2: Define parameter distribution
param_dist = {
    'C': [0.01, 0.1, 1, 5, 10],      
    'max_iter': [1000, 2000, 3000, 5000, 10000], 
}

# Step 3: Randomized search setup
rs = RandomizedSearchCV(
    estimator=model_4,
    param_distributions=param_dist,
    n_iter=10,          # Try 10 combinations
    scoring='accuracy', 
    cv=5,               # 5-fold cross-validation
    n_jobs=-1           # Use all cores
)

# Step 4: Fit the search
rs.fit(X_train_sm, y_train_sm)

# Step 5: Evaluate best model
best_svc_model = rs.best_estimator_
accuracy = best_svc_model.score(X_test_sm, y_test_sm)

print(f"Best Parameters: {rs.best_params_}")
print(f"Model Score: {round(accuracy * 100, 2)}%")
# Out:
# Best Parameters: {'max_iter': 10000, 'C': 0.01}
# Model Score: 91.35%

# %%
y_pred_sm = best_svc_model.predict(X_test_sm)

# %%
best_model_search_accuracy = round((best_svc_model.score(X_test_sm, y_test_sm) * 100), 3)
print(f"Best model after random search accuracy = {best_model_search_accuracy}%")
# Out:
# Best model after random search accuracy = 91.349%

# %%
print(classification_report(y_test_sm, y_pred_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94     22853
#            1       0.85      0.76      0.80      6856
#
#     accuracy                           0.91     29709
#    macro avg       0.89      0.86      0.87     29709
# weighted avg       0.91      0.91      0.91     29709

# %%
cm = confusion_matrix(y_test_sm, y_pred_sm)
cm
# Out:
# array([[21896,   957],
#        [ 1613,  5243]], dtype=int64)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=best_svc_model.classes_)
disp.plot()
plt.show()

# %%
# Show accuracy comparison between all four models (bar chart with labels and accuracy %)
logreg_acc = best_logreg_model.score(X_test_sm, y_test_sm)
knn_acc = best_knn_model.score(X_test_sm, y_test_sm)
rf_acc = best_rf_model.score(X_test_sm, y_test_sm)
svc_acc = best_svc_model.score(X_test_sm, y_test_sm)

models = ['Logistic Regression', 'KNN', 'Random Forest', 'SVC']
accuracies = [logreg_acc, knn_acc, rf_acc, svc_acc]


# Create a figure and a set of subplots with a wider figure size
fig, ax = plt.subplots(figsize=(8, 6))

# Create a bar chart
bars = plt.bar(models, accuracies)

# Set the title and labels
ax.set_title('Accuracy Comparison of Classification Models')
ax.set_ylabel('Accuracy %')

# Loop over the bars and add the accuracy score as text
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 4), va='bottom')

# Display the plot
plt.show()
